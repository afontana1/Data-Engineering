# %%
import os
import sys
import socket

import sys,uuid,datetime
from pyspark.sql import SparkSession
from pyspark import SparkConf, SparkContext

key = os.environ["MINIO_ACCESS_KEY"]
secret = os.environ["MINIO_SECRET_KEY"]
endpoint = os.environ["MINIO_SECRET_ENDPOINT"]
endpoint = "http://192.168.2.128:9000"
print(endpoint)

#sc.stop()

spark = SparkSession.builder \
.master("k8s://https://kubernetes.docker.internal:6443") \
.appName("reading") \
.config("spark.hadoop.fs.s3a.access.key", key) \
.config("spark.hadoop.fs.s3a.secret.key", secret) \
.config("spark.hadoop.fs.s3a.endpoint", endpoint) \
.config("spark.hadoop.fs.s3a.path.style.access", "true") \
.config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
.config("spark.jars.packages", "io.delta:delta-core_2.12:0.7.0,org.apache.hadoop:hadoop-aws:3.2.0,com.amazonaws:aws-java-sdk-bundle:1.11.375") \
.config("spark.delta.logStore.class", "org.apache.spark.sql.delta.storage.S3SingleDriverLogStore") \
.config('spark.submit.deployMode', 'client') \
.config("spark.kubernetes.container.image", "spark:spark-docker") \
.config("spark.kubernetes.pyspark.pythonVersion", "3") \
.config("spark.kubernetes.authenticate.driver.serviceAccountName", "default") \
.config("spark.executor.instances", "1") \
.config("spark.executor.memory", "4g") \
.config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
.config("spark.kubernetes.executor.request.cores","0.5") \
.config("spark.kubernetes.executor.limit.cores","4") \
.config("jupyterService.jupyterPort", "30888") \
.config("serviceAccount", "spark") \
.config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
.config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
.getOrCreate()

#.config("spark.driver.host", "10.1.2.104") \
#.config("spark.driver.port", "4040") \

sc = spark.sparkContext
#sc._conf.getAll()
# Out:
# http://192.168.2.128:9000

# %%
delta_path = "s3a://real-estate/lake/bronze/property"
spark.sql("DESCRIBE FORMATTED delta.`{}`".format(delta_path)).show()
# Out:
# +--------------------+---------+-------+
# |            col_name|data_type|comment|
# +--------------------+---------+-------+
# |propertyDetails_a...|   bigint|       |
# |propertyDetails_a...|   string|       |
# |propertyDetails_a...|   string|       |
# |propertyDetails_c...|   bigint|       |
# |propertyDetails_c...|   string|       |
# |propertyDetails_c...|   bigint|       |
# |propertyDetails_c...|   bigint|       |
# |propertyDetails_d...|   string|       |
# |propertyDetails_g...|   bigint|       |
# |propertyDetails_h...|  boolean|       |
# |propertyDetails_h...|  boolean|       |
# |  propertyDetails_id|   bigint|       |
# |propertyDetails_i...|   string|       |
# |propertyDetails_i...|  boolean|       |
# |propertyDetails_i...|  boolean|       |
# |propertyDetails_i...|   string|       |
# |propertyDetails_i...|  boolean|       |
# |propertyDetails_i...|  boolean|       |
# |propertyDetails_i...|  boolean|       |
# |propertyDetails_l...|   string|       |
# +--------------------+---------+-------+
# only showing top 20 rows

# %%
spark.sql("SELECT COUNT(*) FROM delta.`{}`".format(delta_path)).show()

# %%
import pandas as pd
import json, ijson #made for big files which cannot be handled in memory

#visualisations
import folium
from folium import plugins

# %%
spark.sql("SELECT COUNT(*) FROM delta.`{}`".format(delta_path)).show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |     190|
# +--------+

# %% [markdown]
# # Run Google Direction calculation
# First we prepare Google Way Calculation. Attention, only 2500 request are free per day!

# %%
from googleApiWayCalculation import calculateGoogleDirections

##
## read immoscout files to get property location to lookup in GoogleMaps
## --> Filter here must be changed at some point when Google API request are cheaper or less
##
def loadImmoProperties(file, path, filename):

    #city = file.split('_')[1]

    with open(path + file, 'r') as f:
        objects = ijson.items(f, 'item.propertyDetails')
        props = list(objects)

    p = []
    for prop in props:
        #flatten all dics/arrays inside 
        pp = flatten_json(prop)

        #TODO: change filter only in one place (jupyter notebook)
        if pp['propertyType'] in ['flat', 'penthouse', 'attic-flat', 'duplex-maisonette', 'detached-secondary-suite', 'loft', 'single-room']:
            p.append(flatten_json(prop))

    return p

# %% [markdown]
# ## Here we run Google Way Calculation
# define path, city (bigger city close by you want to go) and place to work. Script will calculate distance and how many times to change train.

# %%
import datetime
path = '/Users/sspaeti/Simon/Sync/Business/13_sspaeti/Real-estate/_DATASETS/immo24/immo24_BS/'


workDestination = 'swissqual, Allmendweg 8, 4528 Zuchwil'

file = 'immo24ads_solothurn_buy_testing.json'
#file = 'immo24ads_bern_buy_2018-06-03_16-34-05.json'
#file = 'immo24ads_solothurn_buy_2018-05-31_19-31-16.json'

cityDestination = 'bern'
cityImmo = file.split('_')[1]
fileOutputName = 'googleDirections_' + cityImmo + '_tester.json'
"""fileOutputName = 'googleDirections_' + cityImmo + '_' + workDestination + '_{timestamp}.json'.format(
    timestamp=datetime.datetime.now().strftime(
        "%Y-%m-%d_%H-%M-%S")  # isoformat('YYYY-MM-DD HH:MM:SS)
)"""

#filters = {'propertyType': ['flat', 'penthouse', 'attic-flat', 'duplex-maisonette', 'detached-secondary-suite', 'loft', 'single-room']}



#get immo data
properties = loadImmoProperties(file, path, file)
calculateGoogleDirections(properties, cityDestination, workDestination, fileOutputName)

# %% [markdown]
# # Loadig data from Delta to Koalas and Pandas

# %%
import databricks.koalas as ks
delta_path = "s3a://real-estate/lake/bronze/property"
delta_table_name='property'
database = 'immo'

#koalas
dfprop = ks.read_delta(delta_path)

#pandas
dfprop_spark = spark.sql("SELECT * FROM delta.`{}`".format(delta_path))
#dfprop = dfprop_spark.toPandas()

#dfprop_spark.show()

dfprop_spark.printSchema()

dfprop.info()
#print(dfprop.index)
#dfprop.head(2)

df = dfprop
# Out:
# root
#  |-- propertyDetails_accountId: long (nullable = true)
#  |-- propertyDetails_availableFrom: string (nullable = true)
#  |-- propertyDetails_availableFromFormatted: string (nullable = true)
#  |-- propertyDetails_cityId: long (nullable = true)
#  |-- propertyDetails_cityName: string (nullable = true)
#  |-- propertyDetails_contactFormTypeId: long (nullable = true)
#  |-- propertyDetails_countryId: long (nullable = true)
#  |-- propertyDetails_description: string (nullable = true)
#  |-- propertyDetails_geoAccuracy: long (nullable = true)
#  |-- propertyDetails_hasNewBuildingProject: boolean (nullable = true)
#  |-- propertyDetails_hasVirtualTour: boolean (nullable = true)
#  |-- propertyDetails_id: long (nullable = true)
#  |-- propertyDetails_isBuyRent: string (nullable = true)
#  |-- propertyDetails_isHighlighted: boolean (nullable = true)
#  |-- propertyDetails_isNew: boolean (nullable = true)
#  |-- propertyDetails_isNewEndDate: string (nullable = true)
#  |-- propertyDetails_isOnline: boolean (nullable = true)
#  |-- propertyDetails_isQualityListing: boolean (nullable = true)
#  |-- propertyDetails_isTopListing: boolean (nullable = true)
#  |-- propertyDetails_lastModified: string (nullable = true)
#  |-- propertyDetails_lastPublished: string (nullable = true)
#  |-- propertyDetails_latitude: double (nullable = true)
#  |-- propertyDetails_listingLayout: long (nullable = true)
#  |-- propertyDetails_longitude: double (nullable = true)
#  |-- propertyDetails_msRegionId: long (nullable = true)
#  |-- propertyDetails_municipalityBfsId: long (nullable = true)
#  |-- propertyDetails_municipalityId: long (nullable = true)
#  |-- propertyDetails_municipalityNameFormatted: string (nullable = true)
#  |-- propertyDetails_normalizedPrice: long (nullable = true)
#  |-- propertyDetails_normalizedPriceFormatted: string (nullable = true)
#  |-- propertyDetails_numberOfRooms: double (nullable = true)
#  |-- propertyDetails_numberOfRoomsFormatted: string (nullable = true)
#  |-- propertyDetails_offerTypeId: long (nullable = true)
#  |-- propertyDetails_packageType: long (nullable = true)
#  |-- propertyDetails_price: long (nullable = true)
#  |-- propertyDetails_priceFormatted: string (nullable = true)
#  |-- propertyDetails_priceUnitId: long (nullable = true)
#  |-- propertyDetails_priceUnitLabel: string (nullable = true)
#  |-- propertyDetails_propertyCategoryId: long (nullable = true)
#  |-- propertyDetails_propertyDetailUrl: string (nullable = true)
#  |-- propertyDetails_propertyId: string (nullable = true)
#  |-- propertyDetails_propertyType: string (nullable = true)
#  |-- propertyDetails_propertyTypeId: long (nullable = true)
#  |-- propertyDetails_referenceNo: string (nullable = true)
#  |-- propertyDetails_regionId: long (nullable = true)
#  |-- propertyDetails_searchCity: string (nullable = true)
#  |-- propertyDetails_searchDate: string (nullable = true)
#  |-- propertyDetails_searchDateTime: string (nullable = true)
#  |-- propertyDetails_searchRadius: long (nullable = true)
#  |-- propertyDetails_sellingPrice: long (nullable = true)
#  |-- propertyDetails_sellingPriceFormatted: string (nullable = true)
#  |-- propertyDetails_shortDescription: string (nullable = true)
#  |-- propertyDetails_showContactForm: boolean (nullable = true)
#  |-- propertyDetails_showContactFormAddress: boolean (nullable = true)
#  |-- propertyDetails_state: string (nullable = true)
#  |-- propertyDetails_stateShort: string (nullable = true)
#  |-- propertyDetails_street: string (nullable = true)
#  |-- propertyDetails_surfaceLiving: long (nullable = true)
#  |-- propertyDetails_surfaceLivingFormatted: string (nullable = true)
#  |-- propertyDetails_surfaceUsable: long (nullable = true)
#  |-- propertyDetails_surfaceUsableFormatted: string (nullable = true)
#  |-- propertyDetails_title: string (nullable = true)
#  |-- propertyDetails_url: string (nullable = true)
#  |-- propertyDetails_urlTitle: string (nullable = true)
#  |-- propertyDetails_videoViewingEnabled: boolean (nullable = true)
#  |-- propertyDetails_visitName: string (nullable = true)
#  |-- propertyDetails_visitPhone: string (nullable = true)
#  |-- propertyDetails_visitRemark: string (nullable = true)
#  |-- propertyDetails_zip: string (nullable = true)
#  |-- propertyDetails_zipId: long (nullable = true)
#  |-- viewData_agencyPhoneStatsUrl: string (nullable = true)
#  |-- viewData_allowOnlineApplication: boolean (nullable = true)
#  |-- viewData_areSimilarPropertiesFromSameAdvertiser: boolean (nullable = true)
#  |-- viewData_debtEnforcementLandingPageUrl: string (nullable = true)
#  |-- viewData_detailPrintStatsUrl: string (nullable = true)
#  |-- viewData_detailViewStatsUrl: string (nullable = true)
#  |-- viewData_financingLinkUrl: string (nullable = true)
#  |-- viewData_movingUrl: string (nullable = true)
#  |-- viewData_showAccountProperties: boolean (nullable = true)
#  |-- viewData_showSimilarProperties: boolean (nullable = true)
#  |-- viewData_visitPhoneStatsUrl: string (nullable = true)
#  |-- propertyDetails_agency_companyCity: string (nullable = true)
#  |-- propertyDetails_agency_companyName1: string (nullable = true)
#  |-- propertyDetails_agency_companyName2: string (nullable = true)
#  |-- propertyDetails_agency_companyPhoneBusiness: string (nullable = true)
#  |-- propertyDetails_agency_companyPhoneMobile: string (nullable = true)
#  |-- propertyDetails_agency_companyStreet: string (nullable = true)
#  |-- propertyDetails_agency_companyZip: string (nullable = true)
#  |-- propertyDetails_agency_firstName: string (nullable = true)
#  |-- propertyDetails_agency_gender: string (nullable = true)
#  |-- propertyDetails_agency_isAccountMigrated: boolean (nullable = true)
#  |-- propertyDetails_agency_isGuest: boolean (nullable = true)
#  |-- propertyDetails_agency_lastName: string (nullable = true)
#  |-- propertyDetails_agency_logoUrl: string (nullable = true)
#  |-- propertyDetails_agency_logoUrlDetailPage: string (nullable = true)
#  |-- propertyDetails_agency_nameFormatted: string (nullable = true)
#  |-- propertyDetails_agency_reference: string (nullable = true)
#  |-- propertyDetails_agency_showLogoOnSerp: boolean (nullable = true)
#  |-- propertyDetails_agency_userType: string (nullable = true)
#  |-- propertyDetails_agency_webUrl: string (nullable = true)
#  |-- propertyDetails_attributes_newBuilding: boolean (nullable = true)
#  |-- propertyDetails_attributes_oldBuilding: boolean (nullable = true)
#  |-- propertyDetails_attributes_underBuildingLaws: boolean (nullable = true)
#  |-- propertyDetails_attributes_yearBuilt: long (nullable = true)
#  |-- propertyDetails_attributes_yearRenovated: long (nullable = true)
#  |-- propertyDetails_attributesInside_animalAllowed: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_cellar: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_firePlace: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_nrBathRooms: long (nullable = true)
#  |-- propertyDetails_attributesInside_propView: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_reduit: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_wheelChairAccessible: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_playGround: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propBalcony: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propChildFriendly: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propElevator: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propGarage: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propParking: boolean (nullable = true)
#  |-- propertyDetails_attributesSize_floor: long (nullable = true)
#  |-- propertyDetails_attributesSize_floorFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSize_numberOfFloors: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceKindergarten: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceKindergartenFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceMotorway: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceMotorwayFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distancePublicTransport: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distancePublicTransportFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceSchool1: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceSchool1Formatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceSchool2: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceSchool2Formatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceShop: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceShopFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_objectSituation: string (nullable = true)
#  |-- propertyDetails_attributesTechnology_dishWasher: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_isMinergieCertified: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_minergieGeneral: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_propCabletv: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_separateTumbleDryer: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_separateWashingMachine: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_steamer: boolean (nullable = true)
#  |-- propertyDetails_videos_description: string (nullable = true)
#  |-- propertyDetails_videos_id: long (nullable = true)
#  |-- propertyDetails_videos_lastModified: string (nullable = true)
#  |-- propertyDetails_videos_remoteId: string (nullable = true)
#  |-- propertyDetails_videos_sortOrder: long (nullable = true)
#  |-- propertyDetails_videos_title: string (nullable = true)
#  |-- propertyDetails_virtualTours_description: string (nullable = true)
#  |-- propertyDetails_virtualTours_id: long (nullable = true)
#  |-- propertyDetails_virtualTours_lastModified: string (nullable = true)
#  |-- propertyDetails_virtualTours_sortOrder: long (nullable = true)
#  |-- propertyDetails_virtualTours_title: string (nullable = true)
#  |-- propertyDetails_virtualTours_url: string (nullable = true)
#  |-- viewData_agencyBusinessImage_description: string (nullable = true)
#  |-- viewData_agencyBusinessImage_id: long (nullable = true)
#  |-- viewData_agencyBusinessImage_lastModified: string (nullable = true)
#  |-- viewData_agencyBusinessImage_originalHeight: long (nullable = true)
#  |-- viewData_agencyBusinessImage_originalWidth: long (nullable = true)
#  |-- viewData_agencyBusinessImage_sortOrder: long (nullable = true)
#  |-- viewData_agencyBusinessImage_title: string (nullable = true)
#  |-- viewData_agencyBusinessImage_url: string (nullable = true)
#  |-- viewData_viewDataWeb_accountPropertiesUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_copyShareUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_fbShareUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_whatsAppShareUrl: string (nullable = true)
#  |-- propertyDetails_commuteTimes_defaultPois_label: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_activeLanguage: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_countImages: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_countPDF: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_country: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_customerType: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_englishVirtualPagePath: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_floorLevel: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasHighlighting: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasToplisting: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasVideoViewing: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasVirtualTour: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasYoutube: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_isCooperation: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_isNewBuilding: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_isShortUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listingId: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_availability: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_cantonName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_locationName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_msregion: long (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_propertyType: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_zip: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_livingSpace: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_localVirtualPagePath: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_numberOfRooms: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_offerTypeName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_packageName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_price: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_streetName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_userCountry: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_userLoggedIn: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_userOrigin: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_viewTab: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_description: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_imageHeight: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_imageType: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_imageUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_imageWidth: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_title: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_url: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@context: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_@type: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_availability: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_description: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_image: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_name: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_price: long (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_priceCurrency: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_url: string (nullable = true)
#  |-- propertyDetails_commuteTimes_defaultPois_defaultPoiId: long (nullable = true)
#  |-- propertyDetails_attributes_swimmingPool: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_attic: boolean (nullable = true)
#  |-- propertyDetails_attributesSize_raisedGroundFloor: boolean (nullable = true)
#  |-- propertyDetails_attributesSize_volume: long (nullable = true)
#  |-- propertyDetails_attributesSize_volumeFormatted: string (nullable = true)
#  |-- propertyDetails_attributesTechnology_minergieCertificateNr: string (nullable = true)
#  |-- propertyDetails_newProjects_imageUrl: string (nullable = true)
#  |-- propertyDetails_newProjects_listUrl: string (nullable = true)
#  |-- propertyDetails_newProjects_name: string (nullable = true)
#  |-- viewData_anibisUrl: string (nullable = true)
#
# <class 'databricks.koalas.frame.DataFrame'>
# Index: 190 entries, 0 to 189
# Data columns (total 226 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   propertyDetails_accountId                                               190 non-null    int64
#  1   propertyDetails_availableFrom                                           57 non-null     object
#  2   propertyDetails_availableFromFormatted                                  190 non-null    object
#  3   propertyDetails_cityId                                                  190 non-null    int64
#  4   propertyDetails_cityName                                                190 non-null    object
#  5   propertyDetails_contactFormTypeId                                       190 non-null    int64
#  6   propertyDetails_countryId                                               190 non-null    int64
#  7   propertyDetails_description                                             189 non-null    object
#  8   propertyDetails_geoAccuracy                                             190 non-null    int64
#  9   propertyDetails_hasNewBuildingProject                                   190 non-null    bool
#  10  propertyDetails_hasVirtualTour                                          190 non-null    bool
#  11  propertyDetails_id                                                      190 non-null    int64
#  12  propertyDetails_isBuyRent                                               190 non-null    object
#  13  propertyDetails_isHighlighted                                           190 non-null    bool
#  14  propertyDetails_isNew                                                   190 non-null    bool
#  15  propertyDetails_isNewEndDate                                            190 non-null    object
#  16  propertyDetails_isOnline                                                190 non-null    bool
#  17  propertyDetails_isQualityListing                                        190 non-null    bool
#  18  propertyDetails_isTopListing                                            190 non-null    bool
#  19  propertyDetails_lastModified                                            190 non-null    object
#  20  propertyDetails_lastPublished                                           190 non-null    object
#  21  propertyDetails_latitude                                                190 non-null    float64
#  22  propertyDetails_listingLayout                                           190 non-null    int64
#  23  propertyDetails_longitude                                               190 non-null    float64
#  24  propertyDetails_msRegionId                                              190 non-null    int64
#  25  propertyDetails_municipalityBfsId                                       190 non-null    int64
#  26  propertyDetails_municipalityId                                          190 non-null    int64
#  27  propertyDetails_municipalityNameFormatted                               190 non-null    object
#  28  propertyDetails_normalizedPrice                                         190 non-null    int64
#  29  propertyDetails_normalizedPriceFormatted                                190 non-null    object
#  30  propertyDetails_numberOfRooms                                           186 non-null    float64
#  31  propertyDetails_numberOfRoomsFormatted                                  186 non-null    object
#  32  propertyDetails_offerTypeId                                             190 non-null    int64
#  33  propertyDetails_packageType                                             190 non-null    int64
#  34  propertyDetails_price                                                   190 non-null    int64
#  35  propertyDetails_priceFormatted                                          190 non-null    object
#  36  propertyDetails_priceUnitId                                             190 non-null    int64
#  37  propertyDetails_priceUnitLabel                                          190 non-null    object
#  38  propertyDetails_propertyCategoryId                                      190 non-null    int64
#  39  propertyDetails_propertyDetailUrl                                       190 non-null    object
#  40  propertyDetails_propertyId                                              190 non-null    object
#  41  propertyDetails_propertyType                                            190 non-null    object
#  42  propertyDetails_propertyTypeId                                          190 non-null    int64
#  43  propertyDetails_referenceNo                                             143 non-null    object
#  44  propertyDetails_regionId                                                190 non-null    int64
#  45  propertyDetails_searchCity                                              190 non-null    object
#  46  propertyDetails_searchDate                                              190 non-null    object
#  47  propertyDetails_searchDateTime                                          190 non-null    object
#  48  propertyDetails_searchRadius                                            190 non-null    int64
#  49  propertyDetails_sellingPrice                                            190 non-null    int64
#  50  propertyDetails_sellingPriceFormatted                                   190 non-null    object
#  51  propertyDetails_shortDescription                                        189 non-null    object
#  52  propertyDetails_showContactForm                                         190 non-null    bool
#  53  propertyDetails_showContactFormAddress                                  190 non-null    bool
#  54  propertyDetails_state                                                   190 non-null    object
#  55  propertyDetails_stateShort                                              190 non-null    object
#  56  propertyDetails_street                                                  159 non-null    object
#  57  propertyDetails_surfaceLiving                                           167 non-null    int64
#  58  propertyDetails_surfaceLivingFormatted                                  167 non-null    object
#  59  propertyDetails_surfaceUsable                                           53 non-null     int64
#  60  propertyDetails_surfaceUsableFormatted                                  53 non-null     object
#  61  propertyDetails_title                                                   190 non-null    object
#  62  propertyDetails_url                                                     32 non-null     object
#  63  propertyDetails_urlTitle                                                32 non-null     object
#  64  propertyDetails_videoViewingEnabled                                     190 non-null    bool
#  65  propertyDetails_visitName                                               57 non-null     object
#  66  propertyDetails_visitPhone                                              56 non-null     object
#  67  propertyDetails_visitRemark                                             9 non-null      object
#  68  propertyDetails_zip                                                     190 non-null    object
#  69  propertyDetails_zipId                                                   190 non-null    int64
#  70  viewData_agencyPhoneStatsUrl                                            190 non-null    object
#  71  viewData_allowOnlineApplication                                         190 non-null    bool
#  72  viewData_areSimilarPropertiesFromSameAdvertiser                         190 non-null    bool
#  73  viewData_debtEnforcementLandingPageUrl                                  190 non-null    object
#  74  viewData_detailPrintStatsUrl                                            190 non-null    object
#  75  viewData_detailViewStatsUrl                                             190 non-null    object
#  76  viewData_financingLinkUrl                                               176 non-null    object
#  77  viewData_movingUrl                                                      190 non-null    object
#  78  viewData_showAccountProperties                                          190 non-null    bool
#  79  viewData_showSimilarProperties                                          190 non-null    bool
#  80  viewData_visitPhoneStatsUrl                                             190 non-null    object
#  81  propertyDetails_agency_companyCity                                      178 non-null    object
#  82  propertyDetails_agency_companyName1                                     181 non-null    object
#  83  propertyDetails_agency_companyName2                                     32 non-null     object
#  84  propertyDetails_agency_companyPhoneBusiness                             144 non-null    object
#  85  propertyDetails_agency_companyPhoneMobile                               61 non-null     object
#  86  propertyDetails_agency_companyStreet                                    177 non-null    object
#  87  propertyDetails_agency_companyZip                                       178 non-null    object
#  88  propertyDetails_agency_firstName                                        60 non-null     object
#  89  propertyDetails_agency_gender                                           57 non-null     object
#  90  propertyDetails_agency_isAccountMigrated                                184 non-null    bool
#  91  propertyDetails_agency_isGuest                                          184 non-null    bool
#  92  propertyDetails_agency_lastName                                         111 non-null    object
#  93  propertyDetails_agency_logoUrl                                          184 non-null    object
#  94  propertyDetails_agency_logoUrlDetailPage                                184 non-null    object
#  95  propertyDetails_agency_nameFormatted                                    60 non-null     object
#  96  propertyDetails_agency_reference                                        54 non-null     object
#  97  propertyDetails_agency_showLogoOnSerp                                   184 non-null    bool
#  98  propertyDetails_agency_userType                                         184 non-null    object
#  99  propertyDetails_agency_webUrl                                           105 non-null    object
#  100 propertyDetails_attributes_newBuilding                                  82 non-null     bool
#  101 propertyDetails_attributes_oldBuilding                                  10 non-null     bool
#  102 propertyDetails_attributes_underBuildingLaws                            5 non-null      bool
#  103 propertyDetails_attributes_yearBuilt                                    157 non-null    int64
#  104 propertyDetails_attributes_yearRenovated                                36 non-null     int64
#  105 propertyDetails_attributesInside_animalAllowed                          86 non-null     bool
#  106 propertyDetails_attributesInside_cellar                                 99 non-null     bool
#  107 propertyDetails_attributesInside_firePlace                              22 non-null     bool
#  108 propertyDetails_attributesInside_nrBathRooms                            60 non-null     int64
#  109 propertyDetails_attributesInside_propView                               88 non-null     bool
#  110 propertyDetails_attributesInside_reduit                                 35 non-null     bool
#  111 propertyDetails_attributesInside_wheelChairAccessible                   66 non-null     bool
#  112 propertyDetails_attributesOutside_playGround                            63 non-null     bool
#  113 propertyDetails_attributesOutside_propBalcony                           152 non-null    bool
#  114 propertyDetails_attributesOutside_propChildFriendly                     115 non-null    bool
#  115 propertyDetails_attributesOutside_propElevator                          135 non-null    bool
#  116 propertyDetails_attributesOutside_propGarage                            141 non-null    bool
#  117 propertyDetails_attributesOutside_propParking                           101 non-null    bool
#  118 propertyDetails_attributesSize_floor                                    146 non-null    int64
#  119 propertyDetails_attributesSize_floorFormatted                           146 non-null    object
#  120 propertyDetails_attributesSize_numberOfFloors                           77 non-null     int64
#  121 propertyDetails_attributesSurrounding_distanceKindergarten              117 non-null    int64
#  122 propertyDetails_attributesSurrounding_distanceKindergartenFormatted     117 non-null    object
#  123 propertyDetails_attributesSurrounding_distanceMotorway                  78 non-null     int64
#  124 propertyDetails_attributesSurrounding_distanceMotorwayFormatted         78 non-null     object
#  125 propertyDetails_attributesSurrounding_distancePublicTransport           108 non-null    int64
#  126 propertyDetails_attributesSurrounding_distancePublicTransportFormatted  108 non-null    object
#  127 propertyDetails_attributesSurrounding_distanceSchool1                   124 non-null    int64
#  128 propertyDetails_attributesSurrounding_distanceSchool1Formatted          124 non-null    object
#  129 propertyDetails_attributesSurrounding_distanceSchool2                   66 non-null     int64
#  130 propertyDetails_attributesSurrounding_distanceSchool2Formatted          66 non-null     object
#  131 propertyDetails_attributesSurrounding_distanceShop                      124 non-null    int64
#  132 propertyDetails_attributesSurrounding_distanceShopFormatted             124 non-null    object
#  133 propertyDetails_attributesSurrounding_objectSituation                   56 non-null     object
#  134 propertyDetails_attributesTechnology_dishWasher                         89 non-null     bool
#  135 propertyDetails_attributesTechnology_isMinergieCertified                13 non-null     bool
#  136 propertyDetails_attributesTechnology_minergieGeneral                    23 non-null     bool
#  137 propertyDetails_attributesTechnology_propCabletv                        89 non-null     bool
#  138 propertyDetails_attributesTechnology_separateTumbleDryer                53 non-null     bool
#  139 propertyDetails_attributesTechnology_separateWashingMachine             57 non-null     bool
#  140 propertyDetails_attributesTechnology_steamer                            31 non-null     bool
#  141 propertyDetails_videos_description                                      6 non-null      object
#  142 propertyDetails_videos_id                                               6 non-null      int64
#  143 propertyDetails_videos_lastModified                                     6 non-null      object
#  144 propertyDetails_videos_remoteId                                         6 non-null      object
#  145 propertyDetails_videos_sortOrder                                        6 non-null      int64
#  146 propertyDetails_videos_title                                            6 non-null      object
#  147 propertyDetails_virtualTours_description                                12 non-null     object
#  148 propertyDetails_virtualTours_id                                         12 non-null     int64
#  149 propertyDetails_virtualTours_lastModified                               12 non-null     object
#  150 propertyDetails_virtualTours_sortOrder                                  12 non-null     int64
#  151 propertyDetails_virtualTours_title                                      12 non-null     object
#  152 propertyDetails_virtualTours_url                                        12 non-null     object
#  153 viewData_agencyBusinessImage_description                                38 non-null     object
#  154 viewData_agencyBusinessImage_id                                         38 non-null     int64
#  155 viewData_agencyBusinessImage_lastModified                               38 non-null     object
#  156 viewData_agencyBusinessImage_originalHeight                             38 non-null     int64
#  157 viewData_agencyBusinessImage_originalWidth                              38 non-null     int64
#  158 viewData_agencyBusinessImage_sortOrder                                  38 non-null     int64
#  159 viewData_agencyBusinessImage_title                                      38 non-null     object
#  160 viewData_agencyBusinessImage_url                                        38 non-null     object
#  161 viewData_viewDataWeb_accountPropertiesUrl                               184 non-null    object
#  162 viewData_viewDataWeb_copyShareUrl                                       190 non-null    object
#  163 viewData_viewDataWeb_fbShareUrl                                         190 non-null    object
#  164 viewData_viewDataWeb_whatsAppShareUrl                                   190 non-null    object
#  165 propertyDetails_commuteTimes_defaultPois_label                          190 non-null    object
#  166 viewData_viewDataWeb_webView_gtmData_activeLanguage                     190 non-null    object
#  167 viewData_viewDataWeb_webView_gtmData_countImages                        190 non-null    object
#  168 viewData_viewDataWeb_webView_gtmData_countPDF                           190 non-null    object
#  169 viewData_viewDataWeb_webView_gtmData_country                            190 non-null    object
#  170 viewData_viewDataWeb_webView_gtmData_customerType                       190 non-null    object
#  171 viewData_viewDataWeb_webView_gtmData_englishVirtualPagePath             190 non-null    object
#  172 viewData_viewDataWeb_webView_gtmData_floorLevel                         146 non-null    object
#  173 viewData_viewDataWeb_webView_gtmData_hasHighlighting                    190 non-null    object
#  174 viewData_viewDataWeb_webView_gtmData_hasToplisting                      190 non-null    object
#  175 viewData_viewDataWeb_webView_gtmData_hasVideoViewing                    190 non-null    object
#  176 viewData_viewDataWeb_webView_gtmData_hasVirtualTour                     190 non-null    object
#  177 viewData_viewDataWeb_webView_gtmData_hasYoutube                         190 non-null    object
#  178 viewData_viewDataWeb_webView_gtmData_isCooperation                      190 non-null    object
#  179 viewData_viewDataWeb_webView_gtmData_isNewBuilding                      190 non-null    object
#  180 viewData_viewDataWeb_webView_gtmData_isShortUrl                         190 non-null    object
#  181 viewData_viewDataWeb_webView_gtmData_listingId                          190 non-null    object
#  182 viewData_viewDataWeb_webView_gtmData_listing_availability               190 non-null    object
#  183 viewData_viewDataWeb_webView_gtmData_listing_cantonName                 190 non-null    object
#  184 viewData_viewDataWeb_webView_gtmData_listing_locationName               190 non-null    object
#  185 viewData_viewDataWeb_webView_gtmData_listing_msregion                   190 non-null    int64
#  186 viewData_viewDataWeb_webView_gtmData_listing_propertyType               190 non-null    object
#  187 viewData_viewDataWeb_webView_gtmData_listing_zip                        190 non-null    object
#  188 viewData_viewDataWeb_webView_gtmData_livingSpace                        167 non-null    object
#  189 viewData_viewDataWeb_webView_gtmData_localVirtualPagePath               190 non-null    object
#  190 viewData_viewDataWeb_webView_gtmData_numberOfRooms                      186 non-null    object
#  191 viewData_viewDataWeb_webView_gtmData_offerTypeName                      190 non-null    object
#  192 viewData_viewDataWeb_webView_gtmData_packageName                        126 non-null    object
#  193 viewData_viewDataWeb_webView_gtmData_price                              190 non-null    object
#  194 viewData_viewDataWeb_webView_gtmData_streetName                         159 non-null    object
#  195 viewData_viewDataWeb_webView_gtmData_userCountry                        190 non-null    object
#  196 viewData_viewDataWeb_webView_gtmData_userLoggedIn                       190 non-null    object
#  197 viewData_viewDataWeb_webView_gtmData_userOrigin                         190 non-null    object
#  198 viewData_viewDataWeb_webView_gtmData_viewTab                            190 non-null    object
#  199 viewData_viewDataWeb_webView_openGraphData_description                  190 non-null    object
#  200 viewData_viewDataWeb_webView_openGraphData_imageHeight                  189 non-null    object
#  201 viewData_viewDataWeb_webView_openGraphData_imageType                    189 non-null    object
#  202 viewData_viewDataWeb_webView_openGraphData_imageUrl                     189 non-null    object
#  203 viewData_viewDataWeb_webView_openGraphData_imageWidth                   189 non-null    object
#  204 viewData_viewDataWeb_webView_openGraphData_title                        190 non-null    object
#  205 viewData_viewDataWeb_webView_openGraphData_url                          190 non-null    object
#  206 viewData_viewDataWeb_webView_structuredData_@context                    20 non-null     object
#  207 viewData_viewDataWeb_webView_structuredData_@graph_@type                20 non-null     object
#  208 viewData_viewDataWeb_webView_structuredData_@graph_availability         20 non-null     object
#  209 viewData_viewDataWeb_webView_structuredData_@graph_description          20 non-null     object
#  210 viewData_viewDataWeb_webView_structuredData_@graph_image                20 non-null     object
#  211 viewData_viewDataWeb_webView_structuredData_@graph_name                 20 non-null     object
#  212 viewData_viewDataWeb_webView_structuredData_@graph_price                20 non-null     int64
#  213 viewData_viewDataWeb_webView_structuredData_@graph_priceCurrency        20 non-null     object
#  214 viewData_viewDataWeb_webView_structuredData_@graph_url                  20 non-null     object
#  215 propertyDetails_commuteTimes_defaultPois_defaultPoiId                   172 non-null    int64
#  216 propertyDetails_attributes_swimmingPool                                 2 non-null      bool
#  217 propertyDetails_attributesInside_attic                                  7 non-null      bool
#  218 propertyDetails_attributesSize_raisedGroundFloor                        4 non-null      bool
#  219 propertyDetails_attributesSize_volume                                   1 non-null      int64
#  220 propertyDetails_attributesSize_volumeFormatted                          1 non-null      object
#  221 propertyDetails_attributesTechnology_minergieCertificateNr              2 non-null      object
#  222 propertyDetails_newProjects_imageUrl                                    34 non-null     object
#  223 propertyDetails_newProjects_listUrl                                     34 non-null     object
#  224 propertyDetails_newProjects_name                                        34 non-null     object
#  225 viewData_anibisUrl                                                      1 non-null      object
# dtypes: bool(42), float64(3), int64(46), object(135)

# %%
dfprop
# Out:
#      propertyDetails_accountId propertyDetails_availableFrom propertyDetails_availableFromFormatted  propertyDetails_cityId propertyDetails_cityName  propertyDetails_contactFormTypeId  propertyDetails_countryId                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 0                       860137     2020-10-27T00:00:00+01:00                            Immediately                     295                     Bern                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             \r\nBeschreibung:\r\n\r\nLage:\r\n\r\nDie attraktiven 7 Mehrfamilienhäuser mit je 5 Wohneinheiten am Hesseweg 10-22 liess der Initiant des Zentrums Paul Klee, Prof. Maurice E. Müller (+) in den Jahren 1997/98 in 2 Bauetappen durch den renommierten Architekten Ulrich Stucky - im Sinne einer Förderung von Wohneigentum für gehobene Ansrprüche - bauen.\r\n\r\nDie moderne Architektur mit der "Tonnendachform" ist zeitlos und passen ausgezeichnet in das Schöngrün-Quartier; eine einmalige Verbindung von "WOHNEN"+KUNST"!                                                     (Distanz: "ein Steinwurf zum Klee")\r\n\r\nObjekt:\r\n\r\nDie Liste der schönen 4,5-Zimmer-Attika-Eiigentumswohnung (140m2) mit einem zusätzlichen Gartenzimmer/Studio(ca.16m2) im UG m ...
# 1                       207510                          None                             On request                     295                     Bern                                  1                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 \r\nDie grosszügige 5-Zimmerwohnung liegt im lebendigen Stadtquartier Wittigkofen in einem Hochhaus mit 64 Wohneinheiten mit Baujahr 1974 (Stockwerkeigentümergemeinschaft Jupiterstrasse 29/31). Sie verfügt über einen praktischen Grundriss mit einem grossen Wohn-/Esszimmer (32 m2) Richtung Süden und Westen, drei Einzelzimmer (15, 15, 11 m2) ebenfalls Richtung Süden, zwei Nasszellen (Badezimmer mit Badewanne (6 m2) und ein sep. ...
# 2                         1087                          None                             On request                     295                     Bern                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        \r\n**PLATEAUX DE BERNE**  \r\n Exklusiv. Urban. Einzigartig.  \r\n \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\r\n\r\n«Plateaux de Berne» – das ist exklusives urbanes Wohnen in Ostermundigen mit Ausblick auf die Stadt Bern und dem Naherholungsgebie ...
# 3                       878494     2020-10-27T00:00:00+01:00                            Immediately                     295                     Bern                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Die Wohnungen in dieser Siedlung wurden 1970 gebaut, um die Bedürfnisse der Wohnungssuchenden in Bezug auf Wohnqualität zu erfüllen.  \r\nAlles in allem eine gelungene Wohnung, die sowohl für Paare als auch für Familien geeignet ist und direkt an die sehr gute Infrastruktur angrenzt. Kindergarten und Grundschule sind zu Fuss erreichbar.  \r\n  \r\nDiese tolle und frisch renovierte 4½ Zimmerwohnung befindet sich im 1. Stock. Neben der neuen Küche wurde  ...
# 4                       715263     2020-10-12T00:00:00+02:00                            Immediately                     295                     Bern                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               \r\nLange Zeit ein beliebter Landgasthof, steht die umgebaute Liegenschaft nun für eine neue Nutzung bereit.\r\ ...
# 5                       826113                          None                             On request                     295                     Bern                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    \r\n**An der Schwabstrasse in 3018 Bern-Bümpliz verkaufen wir eine top ausgebaute 3.5-Zimm ...
# 6                         1008                          None                             On request                     295                     Bern                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Inmitten einer ruhigen und familiären Wohngegend liegt die 3.5-Zimmer-Wohnung in einem hübschen Mehrfamilienhaus. In ...
# 7                        27179                          None                             On request                     295                     Bern                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              \r\n**Oberbottigen Matzenriedstrasse**\r\n\r\n**Die Baueingabe ist erfolgt!**\r\n\r\nAn einer ruhigen und gut erschlossenen Wohnlage erstellen wir eine kleine Ü ...
# 8                        27179                          None                             On request                     295                     Bern                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 9                       304586     2020-10-13T00:00:00+02:00                            Immediately                    1716                 Kehrsatz                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           \r\nDie moderne, hindernisfreie und hochwertig ausgebaute 3 ½-Zimmerwohnung befindet sich im 2. Obergeschoss eines 11-Familienhauses in der Überbauung Bleikenmatt in Kehrsatz.\r\n\r\nDie Raumeinteilung ist grosszügig und der ganze Innenausbau inklusive Nasszelle und Küche hell und zeitlos gewählt. In den beiden Zimmern sowie im Korridorbereich sind Einbauschränke vorhanden. Sämtliche Zimmer sind mit Bodenheizung ausgestattet. In der Nasszelle befindet sich zusätzlich ein Radiator, welcher Ihnen Ihr Handtuch nach dem Duschen kuschlig warm bereit hält.\r\n\r\nZur Wohnflächenerweiterung besteht die Möglichkeit den bestehen ...
# ...
# 187                     773704                          None                             On request                    2596                 Oekingen                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 188                     837011                          None                             On request                    2051          Lohn-Ammannsegg                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 189                     719144                          None                             On request                    1760                    Köniz                                  3                          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %% [markdown]
# # Loading different data sources
# scraped Immoscout properties
# google direction files

# %%
#path = '/Users/sspaeti/Simon/Sync/Business/13_sspaeti/Real-estate/_DATASETS/immo24/immo24_BS/'
#fileImmoSo = 'immo24ads_solothurn_buy_2018-05-31_19-31-16.json'
#fileImmoBe = 'immo24ads_bern_buy_2018-06-03_16-34-05.json'
#fileImmoscout = 'immo24ads_solothurn_buy_testing.json'

def loadImmoScout(fileName, path):
    with open(path + fileName, 'r') as f:
        objects = ijson.items(f, 'item.propertyDetails')
        props = list(objects)    

    p = []
    for prop in props:
        #flatten all dics/arrays inside
        p.append(flatten_json(prop))
    
    #load into pandas dataFrame
    df = pd.DataFrame(p).set_index('id')
    return df

#dfprop = pd.concat([loadImmoScout(fileImmoBe, path), loadImmoScout(fileImmoSo, path)], sort=True)

# %% [markdown]
# ### Loading Google Directions calculations

# %%
fileGoogleSo = 'googleDirections_solothurn_swissqual, Allmendweg 8, 4528 Zuchwil_2018-06-03_23-36-21.json'
#fileGoogleDirections = 'googleDirections_solothurn_tester.json'
fileGoogleBe = 'googleDirections_bern_swissqual, Allmendweg 8, 4528 Zuchwil_2018-06-03_16-37-43.json'

def loadGoogleWayCalc(fileName, path):
    d = json.load( open( path + fileName, 'rb' ) )
    df = pd.DataFrame.from_dict(d)
    df = df.transpose() #switch cols and rows

    #convert integers
    df = df.apply(pd.to_numeric, errors='ignore')
    df.index.name='id'
    df = df.set_index('id')
    return df

#UNION ALL
dfWayCalc = pd.concat([loadGoogleWayCalc(fileGoogleBe, path), loadGoogleWayCalc(fileGoogleSo, path)])

#dfWayCalc.index.name = 'id'
dfWayCalc.info()
#dfWayCalc.index.name
#dfWayCalc.set_index('id', inplace=True)
#print('----1')
#print(dfWayCalc.index)
#print('----2')
#dfWayCalc.head(2)
#print(dfWayCalc.head(2))
#print('----3')
##access specific property:
#print(dfWayCalc.loc['4998203'])

# %% [markdown]
# ### Merge datasets

# %%
"""
print('****')
print(dfWayCalc.loc[4986917])

print('-------')

dfprop.info()
print('****')
dfprop.head(5)
print(dfprop.loc[4986917])

print('-------')
list(dfWayCalc)
list(dfprop)
"""

# %%
df = dfprop.join(dfWayCalc, how='left')
df.info()
df.head(5)
#df.loc[4986917]

# %% [markdown]
# ## Filtering properties

# %%
#reset filters
#df = dfprop.join(dfWayCalc, how='left')

##google way calcualation filters
##no houses
#df = df[df['propertyType'].isin(['flat','penthouse','attic-flat','duplex-maisonette','detached-secondary-suite','loft','single-room'])]
#no more changing trains than two times either to the city or work
#df = df[(df['transitsNoWalkingWork']<=2) & (df['transitsNoWalkingCity']<=2)]

#df = df[(df['routeDurationSecWork']<=50*60) & (df['routeDurationSecCity']<=60*60)]

df = df[df['propertyDetails_normalizedPrice']<=700000]
df.info()
#df.head(5)
#df

# %% [markdown]
# # Reporting
# Top communes of this dataset

# %%
#AUSWERTUNG df
#df.loc[3975183] #direct id
#df.loc[3975183]['longitude']
print(df['propertyDetails_cityName'].value_counts().head(15))
#df.info()

# %% [markdown]
# ## Maps
# ### All properties of this filtered dataset

# %%
file = "201115"
props_map = []
props_map = folium.Map(location=[47.208835, 7.532291],
                       zoom_start=11)
#marker_cluster = folium.plugins.MarkerCluster().add_to(props_map)
for index, row in df.iterrows(): #df.iloc[:100].iterrows():
    link = "https://www.immoscout24.ch/en/d/" + str(row['propertyDetails_id'])
    href = '<a href="' + link + '" target="_blank">' + row["propertyDetails_title"].replace("'", r"\'") + ' - ' + row["propertyDetails_priceFormatted"] + '</a>'
    folium.Marker([row["propertyDetails_latitude"], row["propertyDetails_longitude"]], popup=href).add_to(props_map)
props_map.save("props_map_"+file+".html")
props_map

# %% [markdown]
# ### Heatmap of all properties of this filtered dataset

# %%
props_heatmap = []
props_heatmap = folium.Map(location=[47.208835, 7.532291],
                           zoom_start=10)

#todo, show price as heatmap!
props_heatmap.add_child(plugins.HeatMap([[float(row["propertyDetails_latitude"]), float(row["propertyDetails_longitude"])] for index, row in df.iterrows()]))
props_heatmap.save("heatmap_"+file+".html")
props_heatmap

# %% [markdown]
# # Hedonische Qualitätsberechnung
#
# - Zu den Eigenschaften der Objekte zählen
#   - Strukturvariabeln (z.B. Anzahl Zimmer, Nettowohnfläche, Alter),
#   - Nutzungsvariabeln (Erst-, Zweitwohnung) und
#   - Lagevariablen (z.B. Distanz zum ÖV, Sicht, Exposition, Lärmbelastung).

# %%
#set display row option to show all attributes of df
pd.set_option('display.max_rows', 1000)



display(df.loc[4934218])

df.loc[4934218]['propertyType']
df.loc[4934218]['numberOfRooms']


#Objekttyp
--> propertyType
#Strukturvariablen 
--> numberOfRooms, living (Wohnfläche), surfaceProperty (Grundstücksfläche), surfaceUsable(Nutzfläche) 
  , volume (Kubatur)
  #Altersentwertung 
  , yearBuilt, yearRenovated, newBuilding (also yearBuilt=this year..)
#Lagevariablen
--> routeDurationSecCity (time until next bigger city (choosen from user)), routeDistanceMetersCity
  , routeDurationSecWork, routeDistanceMetersWork
    #Sicht, Exposition, Lärmbelastung
